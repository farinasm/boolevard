# %% [markdown]
# <h1 style="margin-bottom: 0px;">BooLEVARD: Boolean Logical Evaluation of Activation and Repression in Directed pathways</h1>
# <h5 style="margin-bottom: 2px; margin-top: 0px;">Marco Fariñas<sup>1</sup>, Eirini Tsirvouli<sup>2,3</sup>, John Zobolas<sup>4</sup>, Tero Aittokallio<sup>4,5</sup>, Åsmund Flobak<sup>3,6,7</sup>, Kaisa Lehti<sup>1,8</sup></h5>
# <h5 style="margin-top: 3px; margin-bottom: 0px;">doi: </h5>
# <p style="font-size:small">
#     <sup>1</sup>. Department of Biomedical Laboratory Science, Norwegian University of Science and Technology (NTNU), Trondheim, Norway. <br>
#     <sup>2</sup>. Department of Biology, Norwegian University of Science and Technology (NTNU), Trondheim, Norway.<br>
#     <sup>3</sup>. Department of Clinical and Molecular Medicine, Norwegian University of Science and Technology (NTNU), Trondheim, Norway.<br>
#     <sup>4</sup>. Department of Cancer Genomics, Oslo University Hospital (OUH), Oslo, Norway.<br>
#     <sup>5</sup>. Institute for Molecular Medicine Finland, University of Helsinki, Helsinki, Finland.<br>
#     <sup>6</sup>. The Cancer Clinic, St. Olavs Hospital, Trondheim, Norway.<br>
#     <sup>7</sup>. Department of Biotechnology and Nanomedicine, Sintef Industry, Trondheim, Norway.<br>
#     <sup>8</sup>. Department of Microbiology, Tumor and Cell Biology, Karolinska Institute (KI), Stockholm, Sweden.<br>
# </p>
# <h4 style="margin-top: 0px; margin-bottom: 2px; font-size: 1.5em"><b>Use Case 2: Figure and Supplementary Figure source code</b></h4>
# <h4 style="margin-top: 25px; margin-bottom: 0px;"><b><i>Outline</i></b></h4>
# <h6 style="margin-top: 15px; margin-bottom: 0px; font-size : 1em; line-height: 1.5em">
#     <b>0.- Package Load </b><a href="#section-0">[visit]</a><br>
#     <b>1.- Functions </b><a href="#section-1">[visit]</a><br>
#     <b>2.- Scalability Analysis </b><a href="#section-2">[visit]</a><br>
#     2.1.- Random model generation </b><a href="#section-2.1">[visit]</a><br>
#     2.2.- Run BooLEVARD: without parallelization </b><a href="#section-2.1">[visit]</a><br>
#     2.3.- Run BooLEVARD: with parallelization </b><a href="#section-2.2">[visit]</a><br>
#
# </h6>

# %% [markdown]
# <h4 style="margin-top: 0px; margin-bottom: 2px;" id="section-0"><b>0.- Package load</b></h4>

# %%
import random
import numpy as np
from rpy2.robjects import IntVector
from rpy2.robjects.packages import importr
import os
import boolevard as blv
import matplotlib.pyplot as plt
import pandas as pd
import time
import re

boolnet = importr("BoolNet")

# %% [markdown]
# <h4 style="margin-top: 0px; margin-bottom: 2px;" id="section-1"><b>1.- Functions</b></h4>

# %%
def random_bool_expr(regulators):
    expr_parts = []
    for regulator in regulators:
        literal = f"!{regulator}" if random.random() < 0.5 else regulator
        expr_parts.append(literal)
    while len(expr_parts) > 1:
        idx = random.randint(0, len(expr_parts) - 2)
        operator = random.choice([" & ", " | "])
        combined = f"({expr_parts[idx]}{operator}{expr_parts[idx+1]})"
        expr_parts = expr_parts[:idx] + [combined] + expr_parts[idx+2:]
    return expr_parts[0]

def random_bn(n, k_min, k_max, n_inputs, n_models, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    for model_idx in range(1, n_models + 1):
        genes = [f"Gene{i+1}" for i in range(n)]
        input_nodes = set(random.sample(genes, n_inputs))
        rules = []
        total_edges = 0
        for gene in genes:
            if gene in input_nodes:
                rules.append(f"{gene}, {gene}")
                continue
            k = random.randint(k_min, k_max)
            regulators = random.sample([g for g in genes if g != gene], k)
            total_edges += k
            expr = random_bool_expr(regulators)
            rules.append(f"{gene}, {expr}")
        fname = f"randomBN_{n}N{total_edges}E{k_max}KMAX_{model_idx}.bnet"
        fpath = os.path.join(output_dir, fname)
        with open(fpath, "w") as f:
            f.write("\n".join(rules))

        print(f"Saved: {fpath} ({total_edges} edges)")

# %% [markdown]
# <h4 style="margin-top: 0px; margin-bottom: 2px;" id="section-1"><b>2.- Scalability Analysis</b></h4><br>
# <h5 style="margin-top: 0px; margin-bottom: 2px;"  id="section-2.1"><b>2.1.-</b> Random model generation</h5>

# %%
sizes = [20, 30, 40, 50, 60, 70, 80, 90, 100]
max_ks = [2, 3, 4, 5]
for size in sizes:
    for max_k in max_ks:
        random_bn(size, 1, max_k, 3, 20, "random")
# Out:
# Saved: random/randomBN_20N27E2KMAX_1.bnet (27 edges)
# Saved: random/randomBN_20N25E2KMAX_2.bnet (25 edges)
# Saved: random/randomBN_20N24E2KMAX_3.bnet (24 edges)
# Saved: random/randomBN_20N26E2KMAX_4.bnet (26 edges)
# Saved: random/randomBN_20N25E2KMAX_5.bnet (25 edges)
# Saved: random/randomBN_20N23E2KMAX_6.bnet (23 edges)
# Saved: random/randomBN_20N26E2KMAX_7.bnet (26 edges)
# Saved: random/randomBN_20N24E2KMAX_8.bnet (24 edges)
# Saved: random/randomBN_20N26E2KMAX_9.bnet (26 edges)
# Saved: random/randomBN_20N27E2KMAX_10.bnet (27 edges)
# Saved: random/randomBN_20N28E2KMAX_11.bnet (28 edges)
# Saved: random/randomBN_20N25E2KMAX_12.bnet (25 edges)
# Saved: random/randomBN_20N24E2KMAX_13.bnet (24 edges)
# Saved: random/randomBN_20N27E2KMAX_14.bnet (27 edges)
# Saved: random/randomBN_20N28E2KMAX_15.bnet (28 edges)
# Saved: random/randomBN_20N28E2KMAX_16.bnet (28 edges)
# Saved: random/randomBN_20N24E2KMAX_17.bnet (24 edges)
# Saved: random/randomBN_20N23E2KMAX_18.bnet (23 edges)
# Saved: random/randomBN_20N27E2KMAX_19.bnet (27 edges)
# Saved: random/randomBN_20N24E2KMAX_20.bnet (24 edges)
# Saved: random/randomBN_20N36E3KMAX_1.bnet (36 edges)
# Saved: random/randomBN_20N40E3KMAX_2.bnet (40 edges)
# Saved: random/randomBN_20N36E3KMAX_3.bnet (36 edges)
# Saved: random/randomBN_20N35E3KMAX_4.bnet (35 edges)
# Saved: random/randomBN_20N31E3KMAX_5.bnet (31 edges)
# Saved: random/randomBN_20N29E3KMAX_6.bnet (29 edges)
# Saved: random/randomBN_20N33E3KMAX_7.bnet (33 edges)
# Saved: random/randomBN_20N35E3KMAX_8.bnet (35 edges)
# Saved: random/randomBN_20N36E3KMAX_9.bnet (36 edges)
# Saved: random/randomBN_20N29E3KMAX_10.bnet (29 edges)
# Saved: random/randomBN_20N35E3KMAX_11.bnet (35 edges)
# Saved: random/randomBN_20N39E3KMAX_12.bnet (39 edges)
# Saved: random/randomBN_20N38E3KMAX_13.bnet (38 edges)
# Saved: random/randomBN_20N31E3KMAX_14.bnet (31 edges)
# Saved: random/randomBN_20N37E3KMAX_15.bnet (37 edges)
# Saved: random/randomBN_20N37E3KMAX_16.bnet (37 edges)
# Saved: random/randomBN_20N35E3KMAX_17.bnet (35 edges)
# Saved: random/randomBN_20N36E3KMAX_18.bnet (36 edges)
# Saved: random/randomBN_20N37E3KMAX_19.bnet (37 edges)
# Saved: random/randomBN_20N32E3KMAX_20.bnet (32 edges)
# Saved: random/randomBN_20N41E4KMAX_1.bnet (41 edges)
# Saved: random/randomBN_20N36E4KMAX_2.bnet (36 edges)
# Saved: random/randomBN_20N38E4KMAX_3.bnet (38 edges)
# Saved: random/randomBN_20N47E4KMAX_4.bnet (47 edges)
# Saved: random/randomBN_20N37E4KMAX_5.bnet (37 edges)
# Saved: random/randomBN_20N41E4KMAX_6.bnet (41 edges)
# Saved: random/randomBN_20N44E4KMAX_7.bnet (44 edges)
# Saved: random/randomBN_20N50E4KMAX_8.bnet (50 edges)
# Saved: random/randomBN_20N40E4KMAX_9.bnet (40 edges)
# Saved: random/randomBN_20N42E4KMAX_10.bnet (42 edges)
# Saved: random/randomBN_20N35E4KMAX_11.bnet (35 edges)
# Saved: random/randomBN_20N47E4KMAX_12.bnet (47 edges)
# Saved: random/randomBN_20N44E4KMAX_13.bnet (44 edges)
# Saved: random/randomBN_20N47E4KMAX_14.bnet (47 edges)
# Saved: random/randomBN_20N41E4KMAX_15.bnet (41 edges)
# Saved: random/randomBN_20N50E4KMAX_16.bnet (50 edges)
# Saved: random/randomBN_20N35E4KMAX_17.bnet (35 edges)
# Saved: random/randomBN_20N46E4KMAX_18.bnet (46 edges)
# Saved: random/randomBN_20N40E4KMAX_19.bnet (40 edges)
# Saved: random/randomBN_20N44E4KMAX_20.bnet (44 edges)
# Saved: random/randomBN_20N47E5KMAX_1.bnet (47 edges)
# Saved: random/randomBN_20N44E5KMAX_2.bnet (44 edges)
# Saved: random/randomBN_20N57E5KMAX_3.bnet (57 edges)
# Saved: random/randomBN_20N41E5KMAX_4.bnet (41 edges)
# Saved: random/randomBN_20N42E5KMAX_5.bnet (42 edges)
# Saved: random/randomBN_20N59E5KMAX_6.bnet (59 edges)
# Saved: random/randomBN_20N60E5KMAX_7.bnet (60 edges)
# Saved: random/randomBN_20N53E5KMAX_8.bnet (53 edges)
# Saved: random/randomBN_20N48E5KMAX_9.bnet (48 edges)
# Saved: random/randomBN_20N39E5KMAX_10.bnet (39 edges)
# Saved: random/randomBN_20N53E5KMAX_11.bnet (53 edges)
# Saved: random/randomBN_20N46E5KMAX_12.bnet (46 edges)
# Saved: random/randomBN_20N54E5KMAX_13.bnet (54 edges)
# Saved: random/randomBN_20N52E5KMAX_14.bnet (52 edges)
# Saved: random/randomBN_20N54E5KMAX_15.bnet (54 edges)
# Saved: random/randomBN_20N53E5KMAX_16.bnet (53 edges)
# Saved: random/randomBN_20N52E5KMAX_17.bnet (52 edges)
# Saved: random/randomBN_20N43E5KMAX_18.bnet (43 edges)
# Saved: random/randomBN_20N48E5KMAX_19.bnet (48 edges)
# Saved: random/randomBN_20N56E5KMAX_20.bnet (56 edges)
# Saved: random/randomBN_30N37E2KMAX_1.bnet (37 edges)
# Saved: random/randomBN_30N38E2KMAX_2.bnet (38 edges)
# Saved: random/randomBN_30N40E2KMAX_3.bnet (40 edges)
# Saved: random/randomBN_30N41E2KMAX_4.bnet (41 edges)
# Saved: random/randomBN_30N41E2KMAX_5.bnet (41 edges)
# Saved: random/randomBN_30N36E2KMAX_6.bnet (36 edges)
# Saved: random/randomBN_30N43E2KMAX_7.bnet (43 edges)
# Saved: random/randomBN_30N36E2KMAX_8.bnet (36 edges)
# Saved: random/randomBN_30N42E2KMAX_9.bnet (42 edges)
# Saved: random/randomBN_30N41E2KMAX_10.bnet (41 edges)
# Saved: random/randomBN_30N40E2KMAX_11.bnet (40 edges)
# Saved: random/randomBN_30N46E2KMAX_12.bnet (46 edges)
# Saved: random/randomBN_30N38E2KMAX_13.bnet (38 edges)
# Saved: random/randomBN_30N38E2KMAX_14.bnet (38 edges)
# Saved: random/randomBN_30N41E2KMAX_15.bnet (41 edges)
# Saved: random/randomBN_30N41E2KMAX_16.bnet (41 edges)
# Saved: random/randomBN_30N42E2KMAX_17.bnet (42 edges)
# Saved: random/randomBN_30N41E2KMAX_18.bnet (41 edges)
# Saved: random/randomBN_30N40E2KMAX_19.bnet (40 edges)
# Saved: random/randomBN_30N45E2KMAX_20.bnet (45 edges)
# Saved: random/randomBN_30N47E3KMAX_1.bnet (47 edges)
# Saved: random/randomBN_30N57E3KMAX_2.bnet (57 edges)
# Saved: random/randomBN_30N57E3KMAX_3.bnet (57 edges)
# Saved: random/randomBN_30N58E3KMAX_4.bnet (58 edges)
# Saved: random/randomBN_30N52E3KMAX_5.bnet (52 edges)
# Saved: random/randomBN_30N51E3KMAX_6.bnet (51 edges)
# Saved: random/randomBN_30N64E3KMAX_7.bnet (64 edges)
# Saved: random/randomBN_30N51E3KMAX_8.bnet (51 edges)
# Saved: random/randomBN_30N49E3KMAX_9.bnet (49 edges)
# Saved: random/randomBN_30N57E3KMAX_10.bnet (57 edges)
# Saved: random/randomBN_30N51E3KMAX_11.bnet (51 edges)
# Saved: random/randomBN_30N52E3KMAX_12.bnet (52 edges)
# Saved: random/randomBN_30N55E3KMAX_13.bnet (55 edges)
# Saved: random/randomBN_30N51E3KMAX_14.bnet (51 edges)
# Saved: random/randomBN_30N51E3KMAX_15.bnet (51 edges)
# Saved: random/randomBN_30N52E3KMAX_16.bnet (52 edges)
# Saved: random/randomBN_30N54E3KMAX_17.bnet (54 edges)
# Saved: random/randomBN_30N49E3KMAX_18.bnet (49 edges)
# Saved: random/randomBN_30N51E3KMAX_19.bnet (51 edges)
# Saved: random/randomBN_30N50E3KMAX_20.bnet (50 edges)
# Saved: random/randomBN_30N69E4KMAX_1.bnet (69 edges)
# Saved: random/randomBN_30N70E4KMAX_2.bnet (70 edges)
# Saved: random/randomBN_30N64E4KMAX_3.bnet (64 edges)
# Saved: random/randomBN_30N59E4KMAX_4.bnet (59 edges)
# Saved: random/randomBN_30N69E4KMAX_5.bnet (69 edges)
# Saved: random/randomBN_30N62E4KMAX_6.bnet (62 edges)
# Saved: random/randomBN_30N73E4KMAX_7.bnet (73 edges)
# Saved: random/randomBN_30N67E4KMAX_8.bnet (67 edges)
# Saved: random/randomBN_30N72E4KMAX_9.bnet (72 edges)
# Saved: random/randomBN_30N64E4KMAX_10.bnet (64 edges)
# Saved: random/randomBN_30N71E4KMAX_11.bnet (71 edges)
# Saved: random/randomBN_30N72E4KMAX_12.bnet (72 edges)
# Saved: random/randomBN_30N74E4KMAX_13.bnet (74 edges)
# Saved: random/randomBN_30N70E4KMAX_14.bnet (70 edges)
# Saved: random/randomBN_30N68E4KMAX_15.bnet (68 edges)
# Saved: random/randomBN_30N69E4KMAX_16.bnet (69 edges)
# Saved: random/randomBN_30N64E4KMAX_17.bnet (64 edges)
# Saved: random/randomBN_30N67E4KMAX_18.bnet (67 edges)
# Saved: random/randomBN_30N81E4KMAX_19.bnet (81 edges)
# Saved: random/randomBN_30N61E4KMAX_20.bnet (61 edges)
# Saved: random/randomBN_30N74E5KMAX_1.bnet (74 edges)
# Saved: random/randomBN_30N76E5KMAX_2.bnet (76 edges)
# Saved: random/randomBN_30N80E5KMAX_3.bnet (80 edges)
# Saved: random/randomBN_30N82E5KMAX_4.bnet (82 edges)
# Saved: random/randomBN_30N76E5KMAX_5.bnet (76 edges)
# Saved: random/randomBN_30N82E5KMAX_6.bnet (82 edges)
# Saved: random/randomBN_30N88E5KMAX_7.bnet (88 edges)
# Saved: random/randomBN_30N94E5KMAX_8.bnet (94 edges)
# Saved: random/randomBN_30N91E5KMAX_9.bnet (91 edges)
# Saved: random/randomBN_30N75E5KMAX_10.bnet (75 edges)
# Saved: random/randomBN_30N63E5KMAX_11.bnet (63 edges)
# Saved: random/randomBN_30N66E5KMAX_12.bnet (66 edges)
# Saved: random/randomBN_30N75E5KMAX_13.bnet (75 edges)
# Saved: random/randomBN_30N90E5KMAX_14.bnet (90 edges)
# Saved: random/randomBN_30N88E5KMAX_15.bnet (88 edges)
# Saved: random/randomBN_30N70E5KMAX_16.bnet (70 edges)
# Saved: random/randomBN_30N81E5KMAX_17.bnet (81 edges)
# Saved: random/randomBN_30N84E5KMAX_18.bnet (84 edges)
# Saved: random/randomBN_30N75E5KMAX_19.bnet (75 edges)
# Saved: random/randomBN_30N81E5KMAX_20.bnet (81 edges)
# Saved: random/randomBN_40N55E2KMAX_1.bnet (55 edges)
# Saved: random/randomBN_40N56E2KMAX_2.bnet (56 edges)
# Saved: random/randomBN_40N55E2KMAX_3.bnet (55 edges)
# Saved: random/randomBN_40N54E2KMAX_4.bnet (54 edges)
# Saved: random/randomBN_40N55E2KMAX_5.bnet (55 edges)
# Saved: random/randomBN_40N56E2KMAX_6.bnet (56 edges)
# Saved: random/randomBN_40N56E2KMAX_7.bnet (56 edges)
# Saved: random/randomBN_40N61E2KMAX_8.bnet (61 edges)
# Saved: random/randomBN_40N53E2KMAX_9.bnet (53 edges)
# Saved: random/randomBN_40N56E2KMAX_10.bnet (56 edges)
# Saved: random/randomBN_40N55E2KMAX_11.bnet (55 edges)
# Saved: random/randomBN_40N60E2KMAX_12.bnet (60 edges)
# Saved: random/randomBN_40N56E2KMAX_13.bnet (56 edges)
# Saved: random/randomBN_40N56E2KMAX_14.bnet (56 edges)
# Saved: random/randomBN_40N54E2KMAX_15.bnet (54 edges)
# Saved: random/randomBN_40N56E2KMAX_16.bnet (56 edges)
# Saved: random/randomBN_40N52E2KMAX_17.bnet (52 edges)
# Saved: random/randomBN_40N55E2KMAX_18.bnet (55 edges)
# Saved: random/randomBN_40N61E2KMAX_19.bnet (61 edges)
# Saved: random/randomBN_40N57E2KMAX_20.bnet (57 edges)
# Saved: random/randomBN_40N76E3KMAX_1.bnet (76 edges)
# Saved: random/randomBN_40N72E3KMAX_2.bnet (72 edges)
# Saved: random/randomBN_40N68E3KMAX_3.bnet (68 edges)
# Saved: random/randomBN_40N77E3KMAX_4.bnet (77 edges)
# Saved: random/randomBN_40N67E3KMAX_5.bnet (67 edges)
# Saved: random/randomBN_40N80E3KMAX_6.bnet (80 edges)
# Saved: random/randomBN_40N69E3KMAX_7.bnet (69 edges)
# Saved: random/randomBN_40N75E3KMAX_8.bnet (75 edges)
# Saved: random/randomBN_40N80E3KMAX_9.bnet (80 edges)
# Saved: random/randomBN_40N78E3KMAX_10.bnet (78 edges)
# Saved: random/randomBN_40N73E3KMAX_11.bnet (73 edges)
# Saved: random/randomBN_40N85E3KMAX_12.bnet (85 edges)
# Saved: random/randomBN_40N72E3KMAX_13.bnet (72 edges)
# Saved: random/randomBN_40N80E3KMAX_14.bnet (80 edges)
# Saved: random/randomBN_40N67E3KMAX_15.bnet (67 edges)
# Saved: random/randomBN_40N73E3KMAX_16.bnet (73 edges)
# Saved: random/randomBN_40N83E3KMAX_17.bnet (83 edges)
# Saved: random/randomBN_40N75E3KMAX_18.bnet (75 edges)
# Saved: random/randomBN_40N67E3KMAX_19.bnet (67 edges)
# Saved: random/randomBN_40N79E3KMAX_20.bnet (79 edges)
# Saved: random/randomBN_40N88E4KMAX_1.bnet (88 edges)
# Saved: random/randomBN_40N116E4KMAX_2.bnet (116 edges)
# Saved: random/randomBN_40N101E4KMAX_3.bnet (101 edges)
# Saved: random/randomBN_40N86E4KMAX_4.bnet (86 edges)
# Saved: random/randomBN_40N91E4KMAX_5.bnet (91 edges)
# Saved: random/randomBN_40N100E4KMAX_6.bnet (100 edges)
# Saved: random/randomBN_40N98E4KMAX_7.bnet (98 edges)
# Saved: random/randomBN_40N95E4KMAX_8.bnet (95 edges)
# Saved: random/randomBN_40N87E4KMAX_9.bnet (87 edges)
# Saved: random/randomBN_40N93E4KMAX_10.bnet (93 edges)
# Saved: random/randomBN_40N92E4KMAX_11.bnet (92 edges)
# Saved: random/randomBN_40N92E4KMAX_12.bnet (92 edges)
# Saved: random/randomBN_40N91E4KMAX_13.bnet (91 edges)
# Saved: random/randomBN_40N97E4KMAX_14.bnet (97 edges)
# Saved: random/randomBN_40N100E4KMAX_15.bnet (100 edges)
# Saved: random/randomBN_40N104E4KMAX_16.bnet (104 edges)
# Saved: random/randomBN_40N90E4KMAX_17.bnet (90 edges)
# Saved: random/randomBN_40N98E4KMAX_18.bnet (98 edges)
# Saved: random/randomBN_40N92E4KMAX_19.bnet (92 edges)
# Saved: random/randomBN_40N103E4KMAX_20.bnet (103 edges)
# Saved: random/randomBN_40N122E5KMAX_1.bnet (122 edges)
# Saved: random/randomBN_40N110E5KMAX_2.bnet (110 edges)
# Saved: random/randomBN_40N120E5KMAX_3.bnet (120 edges)
# Saved: random/randomBN_40N91E5KMAX_4.bnet (91 edges)
# Saved: random/randomBN_40N102E5KMAX_5.bnet (102 edges)
# Saved: random/randomBN_40N115E5KMAX_6.bnet (115 edges)
# Saved: random/randomBN_40N120E5KMAX_7.bnet (120 edges)
# Saved: random/randomBN_40N100E5KMAX_8.bnet (100 edges)
# Saved: random/randomBN_40N118E5KMAX_9.bnet (118 edges)
# Saved: random/randomBN_40N102E5KMAX_10.bnet (102 edges)
# Saved: random/randomBN_40N112E5KMAX_11.bnet (112 edges)
# Saved: random/randomBN_40N122E5KMAX_12.bnet (122 edges)
# Saved: random/randomBN_40N96E5KMAX_13.bnet (96 edges)
# Saved: random/randomBN_40N107E5KMAX_14.bnet (107 edges)
# Saved: random/randomBN_40N117E5KMAX_15.bnet (117 edges)
# Saved: random/randomBN_40N102E5KMAX_16.bnet (102 edges)
# Saved: random/randomBN_40N110E5KMAX_17.bnet (110 edges)
# Saved: random/randomBN_40N106E5KMAX_18.bnet (106 edges)
# Saved: random/randomBN_40N100E5KMAX_19.bnet (100 edges)
# Saved: random/randomBN_40N96E5KMAX_20.bnet (96 edges)
# Saved: random/randomBN_50N66E2KMAX_1.bnet (66 edges)
# Saved: random/randomBN_50N70E2KMAX_2.bnet (70 edges)
# Saved: random/randomBN_50N70E2KMAX_3.bnet (70 edges)
# Saved: random/randomBN_50N73E2KMAX_4.bnet (73 edges)
# Saved: random/randomBN_50N67E2KMAX_5.bnet (67 edges)
# Saved: random/randomBN_50N67E2KMAX_6.bnet (67 edges)
# Saved: random/randomBN_50N69E2KMAX_7.bnet (69 edges)
# Saved: random/randomBN_50N69E2KMAX_8.bnet (69 edges)
# Saved: random/randomBN_50N68E2KMAX_9.bnet (68 edges)
# Saved: random/randomBN_50N63E2KMAX_10.bnet (63 edges)
# Saved: random/randomBN_50N69E2KMAX_11.bnet (69 edges)
# Saved: random/randomBN_50N74E2KMAX_12.bnet (74 edges)
# Saved: random/randomBN_50N67E2KMAX_13.bnet (67 edges)
# Saved: random/randomBN_50N66E2KMAX_14.bnet (66 edges)
# Saved: random/randomBN_50N75E2KMAX_15.bnet (75 edges)
# Saved: random/randomBN_50N71E2KMAX_16.bnet (71 edges)
# Saved: random/randomBN_50N74E2KMAX_17.bnet (74 edges)
# Saved: random/randomBN_50N69E2KMAX_18.bnet (69 edges)
# Saved: random/randomBN_50N73E2KMAX_19.bnet (73 edges)
# Saved: random/randomBN_50N74E2KMAX_20.bnet (74 edges)
# Saved: random/randomBN_50N95E3KMAX_1.bnet (95 edges)
# Saved: random/randomBN_50N93E3KMAX_2.bnet (93 edges)
# Saved: random/randomBN_50N101E3KMAX_3.bnet (101 edges)
# Saved: random/randomBN_50N92E3KMAX_4.bnet (92 edges)
# Saved: random/randomBN_50N87E3KMAX_5.bnet (87 edges)
# Saved: random/randomBN_50N93E3KMAX_6.bnet (93 edges)
# Saved: random/randomBN_50N98E3KMAX_7.bnet (98 edges)
# Saved: random/randomBN_50N95E3KMAX_8.bnet (95 edges)
# Saved: random/randomBN_50N99E3KMAX_9.bnet (99 edges)
# Saved: random/randomBN_50N99E3KMAX_10.bnet (99 edges)
# Saved: random/randomBN_50N92E3KMAX_11.bnet (92 edges)
# Saved: random/randomBN_50N91E3KMAX_12.bnet (91 edges)
# Saved: random/randomBN_50N94E3KMAX_13.bnet (94 edges)
# Saved: random/randomBN_50N94E3KMAX_14.bnet (94 edges)
# Saved: random/randomBN_50N91E3KMAX_15.bnet (91 edges)
# Saved: random/randomBN_50N85E3KMAX_16.bnet (85 edges)
# Saved: random/randomBN_50N102E3KMAX_17.bnet (102 edges)
# Saved: random/randomBN_50N87E3KMAX_18.bnet (87 edges)
# Saved: random/randomBN_50N88E3KMAX_19.bnet (88 edges)
# Saved: random/randomBN_50N83E3KMAX_20.bnet (83 edges)
# Saved: random/randomBN_50N116E4KMAX_1.bnet (116 edges)
# Saved: random/randomBN_50N116E4KMAX_2.bnet (116 edges)
# Saved: random/randomBN_50N114E4KMAX_3.bnet (114 edges)
# Saved: random/randomBN_50N116E4KMAX_4.bnet (116 edges)
# Saved: random/randomBN_50N122E4KMAX_5.bnet (122 edges)
# Saved: random/randomBN_50N128E4KMAX_6.bnet (128 edges)
# Saved: random/randomBN_50N133E4KMAX_7.bnet (133 edges)
# Saved: random/randomBN_50N98E4KMAX_8.bnet (98 edges)
# Saved: random/randomBN_50N117E4KMAX_9.bnet (117 edges)
# Saved: random/randomBN_50N105E4KMAX_10.bnet (105 edges)
# Saved: random/randomBN_50N107E4KMAX_11.bnet (107 edges)
# Saved: random/randomBN_50N112E4KMAX_12.bnet (112 edges)
# Saved: random/randomBN_50N109E4KMAX_13.bnet (109 edges)
# Saved: random/randomBN_50N133E4KMAX_14.bnet (133 edges)
# Saved: random/randomBN_50N114E4KMAX_15.bnet (114 edges)
# Saved: random/randomBN_50N114E4KMAX_16.bnet (114 edges)
# Saved: random/randomBN_50N109E4KMAX_17.bnet (109 edges)
# Saved: random/randomBN_50N110E4KMAX_18.bnet (110 edges)
# Saved: random/randomBN_50N107E4KMAX_19.bnet (107 edges)
# Saved: random/randomBN_50N92E4KMAX_20.bnet (92 edges)
# Saved: random/randomBN_50N136E5KMAX_1.bnet (136 edges)
# Saved: random/randomBN_50N142E5KMAX_2.bnet (142 edges)
# Saved: random/randomBN_50N156E5KMAX_3.bnet (156 edges)
# Saved: random/randomBN_50N139E5KMAX_4.bnet (139 edges)
# Saved: random/randomBN_50N138E5KMAX_5.bnet (138 edges)
# Saved: random/randomBN_50N149E5KMAX_6.bnet (149 edges)
# Saved: random/randomBN_50N158E5KMAX_7.bnet (158 edges)
# Saved: random/randomBN_50N130E5KMAX_8.bnet (130 edges)
# Saved: random/randomBN_50N135E5KMAX_9.bnet (135 edges)
# Saved: random/randomBN_50N144E5KMAX_10.bnet (144 edges)
# Saved: random/randomBN_50N138E5KMAX_11.bnet (138 edges)
# Saved: random/randomBN_50N135E5KMAX_12.bnet (135 edges)
# Saved: random/randomBN_50N140E5KMAX_13.bnet (140 edges)
# Saved: random/randomBN_50N133E5KMAX_14.bnet (133 edges)
# Saved: random/randomBN_50N137E5KMAX_15.bnet (137 edges)
# Saved: random/randomBN_50N153E5KMAX_16.bnet (153 edges)
# Saved: random/randomBN_50N137E5KMAX_17.bnet (137 edges)
# Saved: random/randomBN_50N135E5KMAX_18.bnet (135 edges)
# Saved: random/randomBN_50N136E5KMAX_19.bnet (136 edges)
# Saved: random/randomBN_50N147E5KMAX_20.bnet (147 edges)
# Saved: random/randomBN_60N89E2KMAX_1.bnet (89 edges)
# Saved: random/randomBN_60N90E2KMAX_2.bnet (90 edges)
# Saved: random/randomBN_60N86E2KMAX_3.bnet (86 edges)
# Saved: random/randomBN_60N85E2KMAX_4.bnet (85 edges)
# Saved: random/randomBN_60N79E2KMAX_5.bnet (79 edges)
# Saved: random/randomBN_60N87E2KMAX_6.bnet (87 edges)
# Saved: random/randomBN_60N80E2KMAX_7.bnet (80 edges)
# Saved: random/randomBN_60N85E2KMAX_8.bnet (85 edges)
# Saved: random/randomBN_60N85E2KMAX_9.bnet (85 edges)
# Saved: random/randomBN_60N87E2KMAX_10.bnet (87 edges)
# Saved: random/randomBN_60N81E2KMAX_11.bnet (81 edges)
# Saved: random/randomBN_60N89E2KMAX_12.bnet (89 edges)
# Saved: random/randomBN_60N81E2KMAX_13.bnet (81 edges)
# Saved: random/randomBN_60N94E2KMAX_14.bnet (94 edges)
# Saved: random/randomBN_60N90E2KMAX_15.bnet (90 edges)
# Saved: random/randomBN_60N82E2KMAX_16.bnet (82 edges)
# Saved: random/randomBN_60N85E2KMAX_17.bnet (85 edges)
# Saved: random/randomBN_60N89E2KMAX_18.bnet (89 edges)
# Saved: random/randomBN_60N90E2KMAX_19.bnet (90 edges)
# Saved: random/randomBN_60N88E2KMAX_20.bnet (88 edges)
# Saved: random/randomBN_60N114E3KMAX_1.bnet (114 edges)
# Saved: random/randomBN_60N113E3KMAX_2.bnet (113 edges)
# Saved: random/randomBN_60N115E3KMAX_3.bnet (115 edges)
# Saved: random/randomBN_60N111E3KMAX_4.bnet (111 edges)
# Saved: random/randomBN_60N117E3KMAX_5.bnet (117 edges)
# Saved: random/randomBN_60N111E3KMAX_6.bnet (111 edges)
# Saved: random/randomBN_60N113E3KMAX_7.bnet (113 edges)
# Saved: random/randomBN_60N113E3KMAX_8.bnet (113 edges)
# Saved: random/randomBN_60N125E3KMAX_9.bnet (125 edges)
# Saved: random/randomBN_60N110E3KMAX_10.bnet (110 edges)
# Saved: random/randomBN_60N105E3KMAX_11.bnet (105 edges)
# Saved: random/randomBN_60N108E3KMAX_12.bnet (108 edges)
# Saved: random/randomBN_60N118E3KMAX_13.bnet (118 edges)
# Saved: random/randomBN_60N119E3KMAX_14.bnet (119 edges)
# Saved: random/randomBN_60N112E3KMAX_15.bnet (112 edges)
# Saved: random/randomBN_60N118E3KMAX_16.bnet (118 edges)
# Saved: random/randomBN_60N118E3KMAX_17.bnet (118 edges)
# Saved: random/randomBN_60N108E3KMAX_18.bnet (108 edges)
# Saved: random/randomBN_60N116E3KMAX_19.bnet (116 edges)
# Saved: random/randomBN_60N125E3KMAX_20.bnet (125 edges)
# Saved: random/randomBN_60N156E4KMAX_1.bnet (156 edges)
# Saved: random/randomBN_60N145E4KMAX_2.bnet (145 edges)
# Saved: random/randomBN_60N148E4KMAX_3.bnet (148 edges)
# Saved: random/randomBN_60N150E4KMAX_4.bnet (150 edges)
# Saved: random/randomBN_60N141E4KMAX_5.bnet (141 edges)
# Saved: random/randomBN_60N146E4KMAX_6.bnet (146 edges)
# Saved: random/randomBN_60N153E4KMAX_7.bnet (153 edges)
# Saved: random/randomBN_60N142E4KMAX_8.bnet (142 edges)
# Saved: random/randomBN_60N137E4KMAX_9.bnet (137 edges)
# Saved: random/randomBN_60N139E4KMAX_10.bnet (139 edges)
# Saved: random/randomBN_60N141E4KMAX_11.bnet (141 edges)
# Saved: random/randomBN_60N130E4KMAX_12.bnet (130 edges)
# Saved: random/randomBN_60N125E4KMAX_13.bnet (125 edges)
# Saved: random/randomBN_60N154E4KMAX_14.bnet (154 edges)
# Saved: random/randomBN_60N131E4KMAX_15.bnet (131 edges)
# Saved: random/randomBN_60N138E4KMAX_16.bnet (138 edges)
# Saved: random/randomBN_60N133E4KMAX_17.bnet (133 edges)
# Saved: random/randomBN_60N143E4KMAX_18.bnet (143 edges)
# Saved: random/randomBN_60N158E4KMAX_19.bnet (158 edges)
# Saved: random/randomBN_60N152E4KMAX_20.bnet (152 edges)
# Saved: random/randomBN_60N182E5KMAX_1.bnet (182 edges)
# Saved: random/randomBN_60N178E5KMAX_2.bnet (178 edges)
# Saved: random/randomBN_60N158E5KMAX_3.bnet (158 edges)
# Saved: random/randomBN_60N163E5KMAX_4.bnet (163 edges)
# Saved: random/randomBN_60N184E5KMAX_5.bnet (184 edges)
# Saved: random/randomBN_60N167E5KMAX_6.bnet (167 edges)
# Saved: random/randomBN_60N158E5KMAX_7.bnet (158 edges)
# Saved: random/randomBN_60N177E5KMAX_8.bnet (177 edges)
# Saved: random/randomBN_60N154E5KMAX_9.bnet (154 edges)
# Saved: random/randomBN_60N173E5KMAX_10.bnet (173 edges)
# Saved: random/randomBN_60N174E5KMAX_11.bnet (174 edges)
# Saved: random/randomBN_60N165E5KMAX_12.bnet (165 edges)
# Saved: random/randomBN_60N173E5KMAX_13.bnet (173 edges)
# Saved: random/randomBN_60N160E5KMAX_14.bnet (160 edges)
# Saved: random/randomBN_60N179E5KMAX_15.bnet (179 edges)
# Saved: random/randomBN_60N183E5KMAX_16.bnet (183 edges)
# Saved: random/randomBN_60N162E5KMAX_17.bnet (162 edges)
# Saved: random/randomBN_60N169E5KMAX_18.bnet (169 edges)
# Saved: random/randomBN_60N162E5KMAX_19.bnet (162 edges)
# Saved: random/randomBN_60N172E5KMAX_20.bnet (172 edges)
# Saved: random/randomBN_70N100E2KMAX_1.bnet (100 edges)
# Saved: random/randomBN_70N99E2KMAX_2.bnet (99 edges)
# Saved: random/randomBN_70N101E2KMAX_3.bnet (101 edges)
# Saved: random/randomBN_70N106E2KMAX_4.bnet (106 edges)
# Saved: random/randomBN_70N98E2KMAX_5.bnet (98 edges)
# Saved: random/randomBN_70N103E2KMAX_6.bnet (103 edges)
# Saved: random/randomBN_70N104E2KMAX_7.bnet (104 edges)
# Saved: random/randomBN_70N99E2KMAX_8.bnet (99 edges)
# Saved: random/randomBN_70N97E2KMAX_9.bnet (97 edges)
# Saved: random/randomBN_70N96E2KMAX_10.bnet (96 edges)
# Saved: random/randomBN_70N98E2KMAX_11.bnet (98 edges)
# Saved: random/randomBN_70N99E2KMAX_12.bnet (99 edges)
# Saved: random/randomBN_70N100E2KMAX_13.bnet (100 edges)
# Saved: random/randomBN_70N106E2KMAX_14.bnet (106 edges)
# Saved: random/randomBN_70N100E2KMAX_15.bnet (100 edges)
# Saved: random/randomBN_70N99E2KMAX_16.bnet (99 edges)
# Saved: random/randomBN_70N101E2KMAX_17.bnet (101 edges)
# Saved: random/randomBN_70N98E2KMAX_18.bnet (98 edges)
# Saved: random/randomBN_70N100E2KMAX_19.bnet (100 edges)
# Saved: random/randomBN_70N102E2KMAX_20.bnet (102 edges)
# Saved: random/randomBN_70N136E3KMAX_1.bnet (136 edges)
# Saved: random/randomBN_70N128E3KMAX_2.bnet (128 edges)
# Saved: random/randomBN_70N147E3KMAX_3.bnet (147 edges)
# Saved: random/randomBN_70N135E3KMAX_4.bnet (135 edges)
# Saved: random/randomBN_70N128E3KMAX_5.bnet (128 edges)
# Saved: random/randomBN_70N133E3KMAX_6.bnet (133 edges)
# Saved: random/randomBN_70N133E3KMAX_7.bnet (133 edges)
# Saved: random/randomBN_70N137E3KMAX_8.bnet (137 edges)
# Saved: random/randomBN_70N141E3KMAX_9.bnet (141 edges)
# Saved: random/randomBN_70N134E3KMAX_10.bnet (134 edges)
# Saved: random/randomBN_70N136E3KMAX_11.bnet (136 edges)
# Saved: random/randomBN_70N123E3KMAX_12.bnet (123 edges)
# Saved: random/randomBN_70N130E3KMAX_13.bnet (130 edges)
# Saved: random/randomBN_70N136E3KMAX_14.bnet (136 edges)
# Saved: random/randomBN_70N135E3KMAX_15.bnet (135 edges)
# Saved: random/randomBN_70N142E3KMAX_16.bnet (142 edges)
# Saved: random/randomBN_70N126E3KMAX_17.bnet (126 edges)
# Saved: random/randomBN_70N133E3KMAX_18.bnet (133 edges)
# Saved: random/randomBN_70N128E3KMAX_19.bnet (128 edges)
# Saved: random/randomBN_70N136E3KMAX_20.bnet (136 edges)
# Saved: random/randomBN_70N167E4KMAX_1.bnet (167 edges)
# Saved: random/randomBN_70N156E4KMAX_2.bnet (156 edges)
# Saved: random/randomBN_70N148E4KMAX_3.bnet (148 edges)
# Saved: random/randomBN_70N161E4KMAX_4.bnet (161 edges)
# Saved: random/randomBN_70N169E4KMAX_5.bnet (169 edges)
# Saved: random/randomBN_70N169E4KMAX_6.bnet (169 edges)
# Saved: random/randomBN_70N157E4KMAX_7.bnet (157 edges)
# Saved: random/randomBN_70N157E4KMAX_8.bnet (157 edges)
# Saved: random/randomBN_70N182E4KMAX_9.bnet (182 edges)
# Saved: random/randomBN_70N169E4KMAX_10.bnet (169 edges)
# Saved: random/randomBN_70N159E4KMAX_11.bnet (159 edges)
# Saved: random/randomBN_70N161E4KMAX_12.bnet (161 edges)
# Saved: random/randomBN_70N175E4KMAX_13.bnet (175 edges)
# Saved: random/randomBN_70N166E4KMAX_14.bnet (166 edges)
# Saved: random/randomBN_70N163E4KMAX_15.bnet (163 edges)
# Saved: random/randomBN_70N165E4KMAX_16.bnet (165 edges)
# Saved: random/randomBN_70N175E4KMAX_17.bnet (175 edges)
# Saved: random/randomBN_70N152E4KMAX_18.bnet (152 edges)
# Saved: random/randomBN_70N170E4KMAX_19.bnet (170 edges)
# Saved: random/randomBN_70N161E4KMAX_20.bnet (161 edges)
# Saved: random/randomBN_70N213E5KMAX_1.bnet (213 edges)
# Saved: random/randomBN_70N196E5KMAX_2.bnet (196 edges)
# Saved: random/randomBN_70N179E5KMAX_3.bnet (179 edges)
# Saved: random/randomBN_70N212E5KMAX_4.bnet (212 edges)
# Saved: random/randomBN_70N175E5KMAX_5.bnet (175 edges)
# Saved: random/randomBN_70N197E5KMAX_6.bnet (197 edges)
# Saved: random/randomBN_70N183E5KMAX_7.bnet (183 edges)
# Saved: random/randomBN_70N197E5KMAX_8.bnet (197 edges)
# Saved: random/randomBN_70N193E5KMAX_9.bnet (193 edges)
# Saved: random/randomBN_70N209E5KMAX_10.bnet (209 edges)
# Saved: random/randomBN_70N201E5KMAX_11.bnet (201 edges)
# Saved: random/randomBN_70N206E5KMAX_12.bnet (206 edges)
# Saved: random/randomBN_70N221E5KMAX_13.bnet (221 edges)
# Saved: random/randomBN_70N234E5KMAX_14.bnet (234 edges)
# Saved: random/randomBN_70N197E5KMAX_15.bnet (197 edges)
# Saved: random/randomBN_70N182E5KMAX_16.bnet (182 edges)
# Saved: random/randomBN_70N218E5KMAX_17.bnet (218 edges)
# Saved: random/randomBN_70N206E5KMAX_18.bnet (206 edges)
# Saved: random/randomBN_70N192E5KMAX_19.bnet (192 edges)
# Saved: random/randomBN_70N204E5KMAX_20.bnet (204 edges)
# Saved: random/randomBN_80N118E2KMAX_1.bnet (118 edges)
# Saved: random/randomBN_80N111E2KMAX_2.bnet (111 edges)
# Saved: random/randomBN_80N116E2KMAX_3.bnet (116 edges)
# Saved: random/randomBN_80N110E2KMAX_4.bnet (110 edges)
# Saved: random/randomBN_80N119E2KMAX_5.bnet (119 edges)
# Saved: random/randomBN_80N121E2KMAX_6.bnet (121 edges)
# Saved: random/randomBN_80N113E2KMAX_7.bnet (113 edges)
# Saved: random/randomBN_80N116E2KMAX_8.bnet (116 edges)
# Saved: random/randomBN_80N120E2KMAX_9.bnet (120 edges)
# Saved: random/randomBN_80N113E2KMAX_10.bnet (113 edges)
# Saved: random/randomBN_80N121E2KMAX_11.bnet (121 edges)
# Saved: random/randomBN_80N113E2KMAX_12.bnet (113 edges)
# Saved: random/randomBN_80N115E2KMAX_13.bnet (115 edges)
# Saved: random/randomBN_80N113E2KMAX_14.bnet (113 edges)
# Saved: random/randomBN_80N114E2KMAX_15.bnet (114 edges)
# Saved: random/randomBN_80N111E2KMAX_16.bnet (111 edges)
# Saved: random/randomBN_80N115E2KMAX_17.bnet (115 edges)
# Saved: random/randomBN_80N117E2KMAX_18.bnet (117 edges)
# Saved: random/randomBN_80N119E2KMAX_19.bnet (119 edges)
# Saved: random/randomBN_80N115E2KMAX_20.bnet (115 edges)
# Saved: random/randomBN_80N147E3KMAX_1.bnet (147 edges)
# Saved: random/randomBN_80N155E3KMAX_2.bnet (155 edges)
# Saved: random/randomBN_80N156E3KMAX_3.bnet (156 edges)
# Saved: random/randomBN_80N162E3KMAX_4.bnet (162 edges)
# Saved: random/randomBN_80N146E3KMAX_5.bnet (146 edges)
# Saved: random/randomBN_80N145E3KMAX_6.bnet (145 edges)
# Saved: random/randomBN_80N157E3KMAX_7.bnet (157 edges)
# Saved: random/randomBN_80N163E3KMAX_8.bnet (163 edges)
# Saved: random/randomBN_80N148E3KMAX_9.bnet (148 edges)
# Saved: random/randomBN_80N147E3KMAX_10.bnet (147 edges)
# Saved: random/randomBN_80N155E3KMAX_11.bnet (155 edges)
# Saved: random/randomBN_80N153E3KMAX_12.bnet (153 edges)
# Saved: random/randomBN_80N159E3KMAX_13.bnet (159 edges)
# Saved: random/randomBN_80N149E3KMAX_14.bnet (149 edges)
# Saved: random/randomBN_80N150E3KMAX_15.bnet (150 edges)
# Saved: random/randomBN_80N152E3KMAX_16.bnet (152 edges)
# Saved: random/randomBN_80N145E3KMAX_17.bnet (145 edges)
# Saved: random/randomBN_80N154E3KMAX_18.bnet (154 edges)
# Saved: random/randomBN_80N151E3KMAX_19.bnet (151 edges)
# Saved: random/randomBN_80N151E3KMAX_20.bnet (151 edges)
# Saved: random/randomBN_80N169E4KMAX_1.bnet (169 edges)
# Saved: random/randomBN_80N192E4KMAX_2.bnet (192 edges)
# Saved: random/randomBN_80N198E4KMAX_3.bnet (198 edges)
# Saved: random/randomBN_80N191E4KMAX_4.bnet (191 edges)
# Saved: random/randomBN_80N209E4KMAX_5.bnet (209 edges)
# Saved: random/randomBN_80N194E4KMAX_6.bnet (194 edges)
# Saved: random/randomBN_80N182E4KMAX_7.bnet (182 edges)
# Saved: random/randomBN_80N188E4KMAX_8.bnet (188 edges)
# Saved: random/randomBN_80N178E4KMAX_9.bnet (178 edges)
# Saved: random/randomBN_80N178E4KMAX_10.bnet (178 edges)
# Saved: random/randomBN_80N189E4KMAX_11.bnet (189 edges)
# Saved: random/randomBN_80N189E4KMAX_12.bnet (189 edges)
# Saved: random/randomBN_80N190E4KMAX_13.bnet (190 edges)
# Saved: random/randomBN_80N181E4KMAX_14.bnet (181 edges)
# Saved: random/randomBN_80N199E4KMAX_15.bnet (199 edges)
# Saved: random/randomBN_80N183E4KMAX_16.bnet (183 edges)
# Saved: random/randomBN_80N197E4KMAX_17.bnet (197 edges)
# Saved: random/randomBN_80N190E4KMAX_18.bnet (190 edges)
# Saved: random/randomBN_80N189E4KMAX_19.bnet (189 edges)
# Saved: random/randomBN_80N184E4KMAX_20.bnet (184 edges)
# Saved: random/randomBN_80N234E5KMAX_1.bnet (234 edges)
# Saved: random/randomBN_80N226E5KMAX_2.bnet (226 edges)
# Saved: random/randomBN_80N218E5KMAX_3.bnet (218 edges)
# Saved: random/randomBN_80N227E5KMAX_4.bnet (227 edges)
# Saved: random/randomBN_80N237E5KMAX_5.bnet (237 edges)
# Saved: random/randomBN_80N236E5KMAX_6.bnet (236 edges)
# Saved: random/randomBN_80N222E5KMAX_7.bnet (222 edges)
# Saved: random/randomBN_80N228E5KMAX_8.bnet (228 edges)
# Saved: random/randomBN_80N241E5KMAX_9.bnet (241 edges)
# Saved: random/randomBN_80N257E5KMAX_10.bnet (257 edges)
# Saved: random/randomBN_80N234E5KMAX_11.bnet (234 edges)
# Saved: random/randomBN_80N224E5KMAX_12.bnet (224 edges)
# Saved: random/randomBN_80N223E5KMAX_13.bnet (223 edges)
# Saved: random/randomBN_80N249E5KMAX_14.bnet (249 edges)
# Saved: random/randomBN_80N221E5KMAX_15.bnet (221 edges)
# Saved: random/randomBN_80N228E5KMAX_16.bnet (228 edges)
# Saved: random/randomBN_80N234E5KMAX_17.bnet (234 edges)
# Saved: random/randomBN_80N226E5KMAX_18.bnet (226 edges)
# Saved: random/randomBN_80N226E5KMAX_19.bnet (226 edges)
# Saved: random/randomBN_80N259E5KMAX_20.bnet (259 edges)
# Saved: random/randomBN_90N126E2KMAX_1.bnet (126 edges)
# Saved: random/randomBN_90N129E2KMAX_2.bnet (129 edges)
# Saved: random/randomBN_90N132E2KMAX_3.bnet (132 edges)
# Saved: random/randomBN_90N131E2KMAX_4.bnet (131 edges)
# Saved: random/randomBN_90N133E2KMAX_5.bnet (133 edges)
# Saved: random/randomBN_90N124E2KMAX_6.bnet (124 edges)
# Saved: random/randomBN_90N138E2KMAX_7.bnet (138 edges)
# Saved: random/randomBN_90N133E2KMAX_8.bnet (133 edges)
# Saved: random/randomBN_90N126E2KMAX_9.bnet (126 edges)
# Saved: random/randomBN_90N125E2KMAX_10.bnet (125 edges)
# Saved: random/randomBN_90N126E2KMAX_11.bnet (126 edges)
# Saved: random/randomBN_90N125E2KMAX_12.bnet (125 edges)
# Saved: random/randomBN_90N132E2KMAX_13.bnet (132 edges)
# Saved: random/randomBN_90N132E2KMAX_14.bnet (132 edges)
# Saved: random/randomBN_90N117E2KMAX_15.bnet (117 edges)
# Saved: random/randomBN_90N134E2KMAX_16.bnet (134 edges)
# Saved: random/randomBN_90N138E2KMAX_17.bnet (138 edges)
# Saved: random/randomBN_90N130E2KMAX_18.bnet (130 edges)
# Saved: random/randomBN_90N135E2KMAX_19.bnet (135 edges)
# Saved: random/randomBN_90N123E2KMAX_20.bnet (123 edges)
# Saved: random/randomBN_90N175E3KMAX_1.bnet (175 edges)
# Saved: random/randomBN_90N168E3KMAX_2.bnet (168 edges)
# Saved: random/randomBN_90N169E3KMAX_3.bnet (169 edges)
# Saved: random/randomBN_90N172E3KMAX_4.bnet (172 edges)
# Saved: random/randomBN_90N167E3KMAX_5.bnet (167 edges)
# Saved: random/randomBN_90N172E3KMAX_6.bnet (172 edges)
# Saved: random/randomBN_90N180E3KMAX_7.bnet (180 edges)
# Saved: random/randomBN_90N162E3KMAX_8.bnet (162 edges)
# Saved: random/randomBN_90N174E3KMAX_9.bnet (174 edges)
# Saved: random/randomBN_90N177E3KMAX_10.bnet (177 edges)
# Saved: random/randomBN_90N164E3KMAX_11.bnet (164 edges)
# Saved: random/randomBN_90N171E3KMAX_12.bnet (171 edges)
# Saved: random/randomBN_90N185E3KMAX_13.bnet (185 edges)
# Saved: random/randomBN_90N164E3KMAX_14.bnet (164 edges)
# Saved: random/randomBN_90N175E3KMAX_15.bnet (175 edges)
# Saved: random/randomBN_90N153E3KMAX_16.bnet (153 edges)
# Saved: random/randomBN_90N167E3KMAX_17.bnet (167 edges)
# Saved: random/randomBN_90N180E3KMAX_18.bnet (180 edges)
# Saved: random/randomBN_90N178E3KMAX_19.bnet (178 edges)
# Saved: random/randomBN_90N174E3KMAX_20.bnet (174 edges)
# Saved: random/randomBN_90N207E4KMAX_1.bnet (207 edges)
# Saved: random/randomBN_90N218E4KMAX_2.bnet (218 edges)
# Saved: random/randomBN_90N211E4KMAX_3.bnet (211 edges)
# Saved: random/randomBN_90N221E4KMAX_4.bnet (221 edges)
# Saved: random/randomBN_90N231E4KMAX_5.bnet (231 edges)
# Saved: random/randomBN_90N202E4KMAX_6.bnet (202 edges)
# Saved: random/randomBN_90N216E4KMAX_7.bnet (216 edges)
# Saved: random/randomBN_90N231E4KMAX_8.bnet (231 edges)
# Saved: random/randomBN_90N218E4KMAX_9.bnet (218 edges)
# Saved: random/randomBN_90N219E4KMAX_10.bnet (219 edges)
# Saved: random/randomBN_90N227E4KMAX_11.bnet (227 edges)
# Saved: random/randomBN_90N213E4KMAX_12.bnet (213 edges)
# Saved: random/randomBN_90N223E4KMAX_13.bnet (223 edges)
# Saved: random/randomBN_90N220E4KMAX_14.bnet (220 edges)
# Saved: random/randomBN_90N202E4KMAX_15.bnet (202 edges)
# Saved: random/randomBN_90N222E4KMAX_16.bnet (222 edges)
# Saved: random/randomBN_90N217E4KMAX_17.bnet (217 edges)
# Saved: random/randomBN_90N212E4KMAX_18.bnet (212 edges)
# Saved: random/randomBN_90N212E4KMAX_19.bnet (212 edges)
# Saved: random/randomBN_90N223E4KMAX_20.bnet (223 edges)
# Saved: random/randomBN_90N241E5KMAX_1.bnet (241 edges)
# Saved: random/randomBN_90N265E5KMAX_2.bnet (265 edges)
# Saved: random/randomBN_90N245E5KMAX_3.bnet (245 edges)
# Saved: random/randomBN_90N277E5KMAX_4.bnet (277 edges)
# Saved: random/randomBN_90N239E5KMAX_5.bnet (239 edges)
# Saved: random/randomBN_90N260E5KMAX_6.bnet (260 edges)
# Saved: random/randomBN_90N252E5KMAX_7.bnet (252 edges)
# Saved: random/randomBN_90N267E5KMAX_8.bnet (267 edges)
# Saved: random/randomBN_90N255E5KMAX_9.bnet (255 edges)
# Saved: random/randomBN_90N262E5KMAX_10.bnet (262 edges)
# Saved: random/randomBN_90N251E5KMAX_11.bnet (251 edges)
# Saved: random/randomBN_90N254E5KMAX_12.bnet (254 edges)
# Saved: random/randomBN_90N260E5KMAX_13.bnet (260 edges)
# Saved: random/randomBN_90N260E5KMAX_14.bnet (260 edges)
# Saved: random/randomBN_90N292E5KMAX_15.bnet (292 edges)
# Saved: random/randomBN_90N258E5KMAX_16.bnet (258 edges)
# Saved: random/randomBN_90N263E5KMAX_17.bnet (263 edges)
# Saved: random/randomBN_90N270E5KMAX_18.bnet (270 edges)
# Saved: random/randomBN_90N259E5KMAX_19.bnet (259 edges)
# Saved: random/randomBN_90N286E5KMAX_20.bnet (286 edges)
# Saved: random/randomBN_100N144E2KMAX_1.bnet (144 edges)
# Saved: random/randomBN_100N144E2KMAX_2.bnet (144 edges)
# Saved: random/randomBN_100N139E2KMAX_3.bnet (139 edges)
# Saved: random/randomBN_100N148E2KMAX_4.bnet (148 edges)
# Saved: random/randomBN_100N153E2KMAX_5.bnet (153 edges)
# Saved: random/randomBN_100N143E2KMAX_6.bnet (143 edges)
# Saved: random/randomBN_100N146E2KMAX_7.bnet (146 edges)
# Saved: random/randomBN_100N136E2KMAX_8.bnet (136 edges)
# Saved: random/randomBN_100N148E2KMAX_9.bnet (148 edges)
# Saved: random/randomBN_100N151E2KMAX_10.bnet (151 edges)
# Saved: random/randomBN_100N144E2KMAX_11.bnet (144 edges)
# Saved: random/randomBN_100N144E2KMAX_12.bnet (144 edges)
# Saved: random/randomBN_100N145E2KMAX_13.bnet (145 edges)
# Saved: random/randomBN_100N146E2KMAX_14.bnet (146 edges)
# Saved: random/randomBN_100N151E2KMAX_15.bnet (151 edges)
# Saved: random/randomBN_100N145E2KMAX_16.bnet (145 edges)
# Saved: random/randomBN_100N141E2KMAX_17.bnet (141 edges)
# Saved: random/randomBN_100N142E2KMAX_18.bnet (142 edges)
# Saved: random/randomBN_100N144E2KMAX_19.bnet (144 edges)
# Saved: random/randomBN_100N143E2KMAX_20.bnet (143 edges)
# Saved: random/randomBN_100N207E3KMAX_1.bnet (207 edges)
# Saved: random/randomBN_100N209E3KMAX_2.bnet (209 edges)
# Saved: random/randomBN_100N190E3KMAX_3.bnet (190 edges)
# Saved: random/randomBN_100N193E3KMAX_4.bnet (193 edges)
# Saved: random/randomBN_100N190E3KMAX_5.bnet (190 edges)
# Saved: random/randomBN_100N197E3KMAX_6.bnet (197 edges)
# Saved: random/randomBN_100N200E3KMAX_7.bnet (200 edges)
# Saved: random/randomBN_100N194E3KMAX_8.bnet (194 edges)
# Saved: random/randomBN_100N200E3KMAX_9.bnet (200 edges)
# Saved: random/randomBN_100N200E3KMAX_10.bnet (200 edges)
# Saved: random/randomBN_100N194E3KMAX_11.bnet (194 edges)
# Saved: random/randomBN_100N205E3KMAX_12.bnet (205 edges)
# Saved: random/randomBN_100N204E3KMAX_13.bnet (204 edges)
# Saved: random/randomBN_100N184E3KMAX_14.bnet (184 edges)
# Saved: random/randomBN_100N196E3KMAX_15.bnet (196 edges)
# Saved: random/randomBN_100N192E3KMAX_16.bnet (192 edges)
# Saved: random/randomBN_100N195E3KMAX_17.bnet (195 edges)
# Saved: random/randomBN_100N196E3KMAX_18.bnet (196 edges)
# Saved: random/randomBN_100N191E3KMAX_19.bnet (191 edges)
# Saved: random/randomBN_100N206E3KMAX_20.bnet (206 edges)
# Saved: random/randomBN_100N237E4KMAX_1.bnet (237 edges)
# Saved: random/randomBN_100N232E4KMAX_2.bnet (232 edges)
# Saved: random/randomBN_100N240E4KMAX_3.bnet (240 edges)
# Saved: random/randomBN_100N254E4KMAX_4.bnet (254 edges)
# Saved: random/randomBN_100N268E4KMAX_5.bnet (268 edges)
# Saved: random/randomBN_100N243E4KMAX_6.bnet (243 edges)
# Saved: random/randomBN_100N251E4KMAX_7.bnet (251 edges)
# Saved: random/randomBN_100N224E4KMAX_8.bnet (224 edges)
# Saved: random/randomBN_100N255E4KMAX_9.bnet (255 edges)
# Saved: random/randomBN_100N260E4KMAX_10.bnet (260 edges)
# Saved: random/randomBN_100N230E4KMAX_11.bnet (230 edges)
# Saved: random/randomBN_100N239E4KMAX_12.bnet (239 edges)
# Saved: random/randomBN_100N231E4KMAX_13.bnet (231 edges)
# Saved: random/randomBN_100N245E4KMAX_14.bnet (245 edges)
# Saved: random/randomBN_100N251E4KMAX_15.bnet (251 edges)
# Saved: random/randomBN_100N224E4KMAX_16.bnet (224 edges)
# Saved: random/randomBN_100N225E4KMAX_17.bnet (225 edges)
# Saved: random/randomBN_100N257E4KMAX_18.bnet (257 edges)
# Saved: random/randomBN_100N243E4KMAX_19.bnet (243 edges)
# Saved: random/randomBN_100N223E4KMAX_20.bnet (223 edges)
# Saved: random/randomBN_100N296E5KMAX_1.bnet (296 edges)
# Saved: random/randomBN_100N331E5KMAX_2.bnet (331 edges)
# Saved: random/randomBN_100N305E5KMAX_3.bnet (305 edges)
# Saved: random/randomBN_100N299E5KMAX_4.bnet (299 edges)
# Saved: random/randomBN_100N288E5KMAX_5.bnet (288 edges)
# Saved: random/randomBN_100N297E5KMAX_6.bnet (297 edges)
# Saved: random/randomBN_100N299E5KMAX_7.bnet (299 edges)
# Saved: random/randomBN_100N280E5KMAX_8.bnet (280 edges)
# Saved: random/randomBN_100N308E5KMAX_9.bnet (308 edges)
# Saved: random/randomBN_100N279E5KMAX_10.bnet (279 edges)
# Saved: random/randomBN_100N289E5KMAX_11.bnet (289 edges)
# Saved: random/randomBN_100N303E5KMAX_12.bnet (303 edges)
# Saved: random/randomBN_100N293E5KMAX_13.bnet (293 edges)
# Saved: random/randomBN_100N321E5KMAX_14.bnet (321 edges)
# Saved: random/randomBN_100N299E5KMAX_15.bnet (299 edges)
# Saved: random/randomBN_100N299E5KMAX_16.bnet (299 edges)
# Saved: random/randomBN_100N275E5KMAX_17.bnet (275 edges)
# Saved: random/randomBN_100N304E5KMAX_18.bnet (304 edges)
# Saved: random/randomBN_100N307E5KMAX_19.bnet (307 edges)
# Saved: random/randomBN_100N307E5KMAX_20.bnet (307 edges)

# %% [markdown]
# <h5 style="margin-top: 0px; margin-bottom: 2px;"  id="section-2.2"><b>2.2.-</b> Run BooLEVARD: without parallelization</h5> <br>
# <div style="
#   border:1px solid #ccc;
#   border-radius:6px;
#   padding:10px;
#   background-color:#f9f9f9;
#   font-size:14px;
#   overflow-x:auto;
#   width:99%;
#   border-left:4px solid #007BFF;
# ">
#
# ```python
# files = sorted(os.listdir("random"), key=lambda x: [int(n) for n in re.findall(r'\d+', x)])
# times, npaths, nss = {}, {}, {}
# for f in files:
#     m = blv.Load(f"random/{f}")
#     if len(m.Info.columns) > 2:
#         t0 = time.time()
#         npaths[f] = sum(sum(abs(x) for x in ss) for ss in m.CountPaths(m.Nodes, ss_wise = True))
#         times[f] = time.time() - t0
#         nss[f] = len(m.Info.columns) - 2
# ```

# %% [markdown]
# <h5 style="margin-top: 0px; margin-bottom: 2px;"  id="section-2.2"><b>2.2.-</b> Run BooLEVARD: with parallelization</h5> <br>
# <div style="
#   border:1px solid #ccc;
#   border-radius:6px;
#   padding:10px;
#   background-color:#f9f9f9;
#   font-size:14px;
#   overflow-x:auto;
#   width:99%;
#   border-left:4px solid #007BFF;
# ">
#
# ```python
# from mpi4py import MPI
# import os, re, time, csv
# import boolevard as blv
#
# comm = MPI.COMM_WORLD
# rank = comm.Get_rank()
# size = comm.Get_size()
#
# WORK_TAG = 1
# STOP_TAG = 0
#
# def process_file(f):
#     m = blv.Load(f"random/{f}")
#     if len(m.Info.columns) <= 2:
#         return None
#     t0 = time.time()
#     npaths = sum(sum(abs(x) for x in ss) for ss in m.CountPaths(m.Nodes, ss_wise=True))
#     return (f, npaths, len(m.Info.columns) - 2, time.time() - t0)
#
# if rank == 0:
#     processed = set()
#     if os.path.exists("results.csv"):
#         with open("results.csv", newline="") as csvfile:
#             reader = csv.reader(csvfile)
#             next(reader, None)
#             for row in reader:
#                 processed.add(row[0])
#     files = sorted(os.listdir("random"), key=lambda x: [int(n) for n in re.findall(r'\d+', x)])
#     files = [f for f in files if f not in processed]
#     files_iter = iter(files)
#     active_workers = 0
#     with open("results.csv", "a" if processed else "w", newline="") as csvfile:
#         writer = csv.writer(csvfile)
#         if not processed:
#             writer.writerow(["file", "npaths", "nss", "time_s"])
#         for worker in range(1, size):
#             try:
#                 f = next(files_iter)
#                 comm.send(f, dest=worker, tag=WORK_TAG)
#                 active_workers += 1
#             except StopIteration:
#                 break
#         finished_workers = 0
#         status = MPI.Status()
#         while finished_workers < active_workers:
#             result = comm.recv(source=MPI.ANY_SOURCE, tag=MPI.ANY_TAG, status=status)
#             worker = status.Get_source()
#             if result is not None:
#                 fname, np, ns, t = result
#                 writer.writerow([fname, np, ns, t])
#                 csvfile.flush()
#             try:
#                 f = next(files_iter)
#                 comm.send(f, dest=worker, tag=WORK_TAG)
#             except StopIteration:
#                 comm.send(None, dest=worker, tag=STOP_TAG)
#                 finished_workers += 1
# else:
#     status = MPI.Status()
#     while True:
#         f = comm.recv(source=0, tag=MPI.ANY_TAG, status=status)
#         tag = status.Get_tag()
#         if tag == STOP_TAG or f is None:
#             break
#         result = process_file(f)
#         comm.send(result, dest=0)

# %% [markdown]
# <h4 style="margin-top: 0px; margin-bottom: 2px;" id="section-1"><b>3.- Figure 7:</b> Scalability Results</h4><br>

# %%
sc = pd.read_csv("Tables/results.csv")
sc[["nodes","edges","k_max"]] = sc["file"].str.extract(r"(\d+)N(\d+)E(\d+)KMAX").astype(int)
sc["t_ss"] = sc["time_s"]/sc["nss"]
sc["p_ss"] = sc["npaths"]/sc["nss"]
g1 = sc.groupby(["nodes","k_max"])["t_ss"].mean().unstack("k_max")
g2 = sc.groupby(["nodes","k_max"])["p_ss"].mean().unstack("k_max")
colors = {2:"#FFD700",3:"#FFA500",4:"#FF4500",5:"#FF1493"}

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
for k in g1.columns:
    xs, ys = g1.index, g1[k]
    ax1.plot(xs, ys, marker="o", color=colors[k], linewidth=2)
    ax1.text(xs[-1]+3, ys.iloc[-1], f"k_max={k}", va="center", color=colors[k])
for k in colors:
    dfk = sc[sc["k_max"]==k]
    ax1.scatter(dfk["nodes"], dfk["t_ss"], s=3, alpha=0.6, color=colors[k])
base_ys = [30000, 20000, 12750, 8500]
ks_desc = sorted(colors.keys(), reverse=True)
for x in g1.index:
    for y, k in zip(base_ys, ks_desc):
        dfkx = sc[(sc["nodes"]==x)&(sc["k_max"]==k)]
        mn, mx = dfkx["edges"].min(), dfkx["edges"].max()
        ax1.text(x, y, f"[{mn},{mx}]", ha="center", va="center", fontsize=6, color=colors[k], fontweight="bold")
ax1.set_xlim(10, 120)
ax1.set_ylim(0.01, 50000)
ax1.set_xlabel("Model Size (#N)", fontsize=12)
ax1.set_yscale("log")
ticks = [0.01, 1, 100, 1000]
ax1.set_yticks(ticks)
ax1.set_yticklabels([f"{s}s" for s in ticks])
ax1.set_ylabel("Avg. time / stable state (log-scaled)", fontsize=12)
ax1.grid(axis="y", linestyle="--", alpha=1, linewidth=1)
ax1.tick_params(axis="y", which="both", length=0)

for k in g2.columns:
    xs, ys = g2.index, g2[k]
    ax2.plot(xs, ys, marker="o", color=colors[k], linewidth=2)
    ax2.text(xs[-1]+3, ys.iloc[-1], f"k_max={k}", va="center", color=colors[k])
for k in colors:
    dfk = sc[sc["k_max"]==k]
    ax2.scatter(dfk["nodes"], dfk["p_ss"], s=3, alpha=0.6, color=colors[k])
ax2.set_xlim(15, 120)
ax2.set_xlabel("Model Size (#N)", fontsize=12)
ax2.set_yscale("log")
ax2.set_ylabel("Avg. paths per stable state (log-scaled)", fontsize=12)
ax2.yaxis.set_major_locator(plt.LogLocator(base=10.0, numticks=4))
ax2.grid(axis="y", which="major", linestyle="--", alpha=1, linewidth=1)
ax2.tick_params(axis="y", which="both", length=0)

plt.tight_layout()
plt.show()
fig.savefig("Figures/png/Figure_7.png", dpi=300, bbox_inches="tight")
fig.savefig("Figures/pdf/Figure_7.pdf", dpi=300, bbox_inches="tight")

# %% [markdown]
# <p>
#     <b>Figure 7: A. </b>Log-scaled marker-line chart of BooLEVARD's average simulation time per stable state for path enumeration in random Boolean networks of size N = 20, 40, 60, 80, and 100 nodes with a discrete uniform in-degree distribution from 1 to k = 2 (pink), 3 (red), 4 (orange), and 5 (yellow). Individual models are overlaid as smaller scatter points. Above each data point, the [min, max] range of edges for the network configuration is annotated in the corresponding color group.<b> B. </b> Log-scaled marker-line chart of BooLEVARD's average path enumeration per stable state in random Boolean networks of size N = 20, 40, 60, 80, and 100 nodes with a discrete uniform in-degree distribution from 1 to k = 2 (pink), 3 (red), 4 (orange), and 5 (yellow). Individual models are overlaid as smaller scatter points.
# </p>
